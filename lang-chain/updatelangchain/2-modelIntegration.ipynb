# %% [markdown]
# Model Integration with Gemini ,Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv("GOOGLE_API_KEY")
os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# GROQ MODEL

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:openai/gpt-oss-120b")
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.1'}}, profile={'name': 'GPT OSS 120B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000002E01CD0A660>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002E01CD0B0E0>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
## Groq model
import os
from langchain_groq import ChatGroq 
model = ChatGroq(model="openai/gpt-oss-120b", groq_api_key=os.environ['GROQ_API_KEY'])
##invoke the model
res=model.invoke("Hello, how are you?")
res.content
# Out:
# "Hello! I'm doing great, thank you for asking. How can I assist you today?"

# %%
##invoke the model
res=model.invoke("Hello, how are you?")
res.content
# Out:
# "Hello! I'm doing well, thank you for asking. How can I assist you today?"

# %% [markdown]
# Google Gemini Model

# %%
## Google Gemini model
import os
from langchain.chat_models import init_chat_model
os.environ['GOOGLE_API_KEY'] = os.getenv("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
##invoke the model
res=model.invoke("Hello, how are you?")
res.content
# Out:
# "Hello! I am doing well, thank you for asking. As a large language model, I don't experience feelings in the same way humans do, but I'm functioning optimally and ready to assist you.\n\nHow are *you* doing today? I hope you're having a good day!"

# %%
## Google Gemini model
import os
from langchain_google_genai import ChatGoogleGenerativeAI
os.environ['GOOGLE_API_KEY'] = os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", google_api_key=os.environ['GOOGLE_API_KEY'])
##invoke the model
res=model.invoke("Hello, how are you?")
res.content
# Out:
# "Hello! I'm doing great, thank you for asking. As a large language model, I don't experience feelings in the same way humans do, but I'm functioning optimally and ready to assist you.\n\nHow are you doing today? Is there anything I can help you with?"

# %% [markdown]
# STREAMING

# %%
for chunk in model.stream("write a poem about the moon in 200 words"):
    print(chunk.text, end="" , flush=True)
# Out:
# Silver sentinel of night, you rise
# from the hush of twilight's veil,
# a pale lantern drifting
# over seas of dreaming clouds,
# whispering ancient lullabies
# to the sleeping world.
#
# Your cratered face, a map
# of stories etched in dust,
# holds the sighs of lovers,
# the promises of wanderers,
# and the silent prayers
# of those who gaze upward,
# seeking solace in your glow.
#
# Each night you wax and wane,
# a celestial metronome
# ticking the rhythm
# of tides and tides of time,
# drawing tides of hearts
# to the shore of night,
# where shadows dance
# in your silvered light.
#
# Even when clouds veil your face,
# the world still feels your pull,
# a quiet reminder
# that even darkness holds
# a luminous promise,
# that every ending
# is a circle,
# and every circle
# begins anew.
#
# Moon, you are the poet's muse,
# the sailor's compass,
# the lover's sigh,
# the child's wonder,
# the ancient's myth.
# In your glow we find
# the fragile thread
# that ties the present
# ...

# %% [markdown]
# Batch

# %% [markdown]
# Batching a collection of independent req to a model cam significantly improve performance and reduce costs,as the processing can be done in parallel:

# %%
res = model.batch([
    "write a poem about the moon in 20 words",
    "Hello, how are you?",
    "What is the capital of France?"
])
for r in res:
    print(r.content)
# Out:
# Silver sentinel, night’s whisper, tides obey your pull; pale lover, dreaming sky, cradles secrets in quiet glow, eternal, soft, lullaby.
# Hello! I'm doing great, thank you for asking. How can I help you today?
# The capital of France is **Paris**.

# %%
res = model.batch([
    "write a poem about the moon in 20 words",
    "Hello, how are you?",
    "What is the capital of France?"],
    config={
        'max_concurrency': 5, # LIMIT TO 5 PARALLEL REQUESTS
    })
